# %% [markdown]
# # CFM56-5B — 2D/3D Vizualizáció
# Állomás-diagram, T-s diagram és interaktív 3D hajtőmű modell.

# %%
import sys
sys.path.insert(0, '..')
from engine import run_design_point
from visualization import plot_station_diagram, plot_ts_diagram, plot_3d_model

takeoff = run_design_point(flight_phase='takeoff', altitude_ft=0,     mach=0.25)
cruise  = run_design_point(flight_phase='cruise',  altitude_ft=35000, mach=0.82)

# %% [markdown]
# ## 2D Állomás-diagram — Felszállás

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

fig = plot_station_diagram(takeoff)
fig.savefig('stations_takeoff.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## T-s diagram — Felszállás vs Cruise

# %%
fig2 = plot_ts_diagram([takeoff, cruise])
fig2.savefig('ts_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3D Hajtőmű Modell

# %%
fig3d = plot_3d_model(takeoff)
fig3d.write_html('cfm56_3d.html')
print('3D modell mentve: cfm56_3d.html')
fig3d.show()
